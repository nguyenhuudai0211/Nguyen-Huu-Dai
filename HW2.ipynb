# %%
def xac_dinh_gia_grab(khoang_cach, luu_luong, thoi_tiet, diem_thuong):
    if khoang_cach == 'ngan' and luu_luong == 'thap' and diem_thuong == 'khong':
        return "Giá thấp"
    elif khoang_cach == 'ngan' and luu_luong == 'trung_binh' and diem_thuong == 'khong':
        return "Giá thấp"
    elif khoang_cach == 'ngan' and luu_luong == 'cao' and diem_thuong == 'khong':
        return "Giá trung bình"
    elif khoang_cach == 'trung_binh' and luu_luong == 'thap' and diem_thuong == 'khong':
        return "Giá trung bình"
    elif khoang_cach == 'trung_binh' and luu_luong == 'trung_binh' and diem_thuong == 'khong':
        return "Giá trung bình"
    elif khoang_cach == 'trung_binh' and luu_luong == 'cao' and diem_thuong == 'khong':
        return "Giá cao"
    elif khoang_cach == 'xa' and luu_luong == 'thap' and diem_thuong == 'khong':
        return "Giá trung bình"
    elif khoang_cach == 'xa' and luu_luong == 'trung_binh' and diem_thuong == 'khong':
        return "Giá cao"
    elif khoang_cach == 'xa' and luu_luong == 'cao' and diem_thuong == 'khong':
        return "Giá rất cao"
    elif khoang_cach == 'trung_binh' and luu_luong == 'trung_binh' and thoi_tiet == 'xau':
        return "Giá rất cao"
    elif khoang_cach == 'xa' and luu_luong == 'trung_binh' and thoi_tiet == 'xau':
        return "Giá rất cao"
    elif khoang_cach == 'xa' and luu_luong == 'trung_binh' and diem_thuong == 'co':
        return "Giá trung bình"
    elif khoang_cach == 'ngan' and luu_luong == 'thap' and diem_thuong == 'co':
        return "Giá rất thấp"
    else:
        return "Giá trung bình (Mặc định)"
kq = xac_dinh_gia_grab(khoang_cach='xa',
                       luu_luong='cao',
                       thoi_tiet='tot',
                       diem_thuong='khong')

print("=== HỆ THỐNG TÍNH CƯỚC GRAB-BIKE ===")
print(f"Kết quả cho đơn hàng của bạn: {kq}")
data = [('ngan', 'thap', 'tot', 'khong'), ('xa', 'cao', 'tot', 'khong'),
        ('trung_binh', 'cao', 'tot', 'khong'), ('xa', 'trung_binh', 'xau', 'khong'),
        ('ngan', 'thap', 'tot', 'co')]
def get_price(k, l, t, d):
    if d == 'co': return "Giá ưu đãi"
    if t == 'xau': return "Giá rất cao"
    if k == 'xa' and l == 'cao': return "Giá rất cao"
    if k == 'ngan' and l == 'thap': return "Giá thấp"
    return "Giá trung bình"
for i in data:
    print(f"Đơn hàng {i}: -> {get_price(*i)}")
# Out:
# === HỆ THỐNG TÍNH CƯỚC GRAB-BIKE ===
# Kết quả cho đơn hàng của bạn: Giá rất cao
# Đơn hàng ('ngan', 'thap', 'tot', 'khong'): -> Giá thấp
# Đơn hàng ('xa', 'cao', 'tot', 'khong'): -> Giá rất cao
# Đơn hàng ('trung_binh', 'cao', 'tot', 'khong'): -> Giá trung bình
# Đơn hàng ('xa', 'trung_binh', 'xau', 'khong'): -> Giá rất cao
# Đơn hàng ('ngan', 'thap', 'tot', 'co'): -> Giá ưu đãi

# %%
nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam = "cao", "thap", "thap", "thap", "thap"
print("Don hang 1:")
if nhu_cau == "cao" and bien_loi_nhuan == "thap":
    print("Ket qua: Chiet khau rat thap (0-5%)")
else:
    print("Ket qua: Chiet khau thap")
nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam = "cao", "thap", "thap", "cao", "thap"
print("\nDon hang 2:")
if nhu_cau == "cao" and bien_loi_nhuan == "cao":
    print("Ket qua: Chiet khau cao (20-40%)")
else:
    print("Ket qua: Khong xac dinh")
nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam = "trung_binh", "trung_binh", "trung_binh", "trung_binh", "trung_binh"
print("\nDon hang 3:")
if uy_tin == "trung_binh" and ap_luc == "trung_binh":
    print("Ket qua: Chiet khau trung binh (10-20%)")
else:
    print("Ket qua: Khong xac dinh")
nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam = "cao", "cao", "thap", "cao", "thap"
print("\nDon hang 4:")
if ap_luc == "cao" and bien_loi_nhuan == "cao":
    print("Ket qua: Chiet khau rat cao (40-70%)")
else:
    print("Ket qua: Khong xac dinh")
nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam = "thap", "thap", "thap", "cao", "trung_binh"
print("\nDon hang 5:")
if bien_loi_nhuan == "cao" and mua_mua_sam == "trung_binh":
    print("Ket qua: Chiet khau trung binh (10-20%)")
else:
    print("Ket qua: Khong xac dinh")
# Out:
# Don hang 1:
# Ket qua: Chiet khau rat thap (0-5%)
#
# Don hang 2:
# Ket qua: Chiet khau cao (20-40%)
#
# Don hang 3:
# Ket qua: Chiet khau trung binh (10-20%)
#
# Don hang 4:
# Ket qua: Chiet khau rat cao (40-70%)
#
# Don hang 5:
# Ket qua: Chiet khau trung binh (10-20%)

# %%
def tinh_giam_gia(nhu_cau, ap_luc, uy_tin, bien_loi_nhuan, mua_mua_sam):
    if nhu_cau == "cao" and ap_luc == "thap" and bien_loi_nhuan == "thap":
        return "Giam gia rat thap (0-5%)"
    elif nhu_cau == "thap" and ap_luc == "cao" and bien_loi_nhuan == "cao":
        return "Chiet khau cao (20-40%)"
    elif uy_tin == "cao" and bien_loi_nhuan == "trung_binh" and mua_mua_sam == "cao":
        return "Chiet khau trung binh (10-20%)"
    elif ap_luc == "cao" and mua_mua_sam == "cao" and bien_loi_nhuan == "cao":
        return "Chiet khau rat cao (40-70%)"
    elif uy_tin == "thap" and mua_mua_sam == "trung_binh" and bien_loi_nhuan == "thap":
        return "Chiet khau trung binh (10-20%)"
    elif nhu_cau == "cao" and mua_mua_sam == "khong" and ap_luc == "thap":
        return "Chiet khau thap (5-10%)"
    elif bien_loi_nhuan == "cao" and ap_luc == "trung_binh" and mua_mua_sam == "trung_binh":
        return "Chiet khau trung binh (10-20%)"
    else:
        return "Chiet khau thap (Mac dinh)"
print("--- KET QUA CHIEN LUOC BAN HANG SHOPEE ---")
print("Don hang 1:", tinh_giam_gia("cao", "thap", "thap", "thap", "khong"))
print("Don hang 2:", tinh_giam_gia("thap", "cao", "thap", "cao", "khong"))
print("Don hang 3:", tinh_giam_gia("trung_binh", "trung_binh", "cao", "trung_binh", "cao"))
print("Don hang 4:", tinh_giam_gia("trung_binh", "cao", "trung_binh", "cao", "cao"))
print("Don hang 5:", tinh_giam_gia("thap", "thap", "thap", "cao", "trung_binh"))
# Out:
# --- KET QUA CHIEN LUOC BAN HANG SHOPEE ---
# Don hang 1: Giam gia rat thap (0-5%)
# Don hang 2: Chiet khau cao (20-40%)
# Don hang 3: Chiet khau trung binh (10-20%)
# Don hang 4: Chiet khau rat cao (40-70%)
# Don hang 5: Chiet khau thap (Mac dinh)

# %%
def tinh_giao_nhan(mat_do, tai_trong, tinh_trang_gt, muc_khan_cap, loi_nhuan):
    if mat_do == "cao" and tai_trong == "thap" and tinh_trang_gt == "thong_thoang":
        ket_hop = "Ket hop nhieu don hang (Toi uu hoa)"
    elif mat_do == "trung_binh" and tinh_trang_gt == "cao" and muc_khan_cap == "cao":
        ket_hop = "Ket hop mot vai don hang (Tranh cham tre)"
    elif tai_trong == "cao" and mat_do == "cao" and loi_nhuan == "trung_binh":
        ket_hop = "Ket hop mot so don hang (Tranh qua tai)"
    else:
        ket_hop = "Ket hop it don hang (Uu tien toc do)"
    if muc_khan_cap == "cao" and loi_nhuan == "cao":
        uu_tien = "Uu tien giao hang truoc"
    elif muc_khan_cap == "trung_binh" and tinh_trang_gt == "trung_binh":
        uu_tien = "Uu tien giao hang trung binh"
    else:
        uu_tien = "Giao hang sau"
    return ket_hop, uu_tien
print(f"{'KET HOP DON':<40} | {'UU TIEN GIAO'}")
print("-" * 70)
data_test = [
    ("cao", "thap", "thong_thoang", "cao", "trung_binh"),
    ("trung_binh", "thap", "cao", "cao", "trung_binh"),
    ("thap", "cao", "cao", "thap", "thap"),
    ("cao", "cao", "trung_binh", "trung_binh", "trung_binh"),
    ("trung_binh", "trung_binh", "trung_binh", "trung_binh", "trung_binh")
]
for d in data_test:
    kh, ut = tinh_giao_nhan(*d)
    print(f"{kh:<40} | {ut}")
# Out:
# KET HOP DON                              | UU TIEN GIAO
# ----------------------------------------------------------------------
# Ket hop nhieu don hang (Toi uu hoa)      | Giao hang sau
# Ket hop mot vai don hang (Tranh cham tre) | Giao hang sau
# Ket hop it don hang (Uu tien toc do)     | Giao hang sau
# Ket hop mot so don hang (Tranh qua tai)  | Uu tien giao hang trung binh
# Ket hop it don hang (Uu tien toc do)     | Uu tien giao hang trung binh
